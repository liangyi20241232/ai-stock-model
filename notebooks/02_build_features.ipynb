# %% [markdown]
# # 02 生成特征和标签
#
# 正式运行建议在终端执行：`python main.py build-features`。

# %%
from src.features import build_features
from src.labels import build_dataset

# build_features()
# build_dataset()
