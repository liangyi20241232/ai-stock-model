# %% [markdown]
# # 04 回测
#
# 正式运行建议依次执行：`python main.py portfolio`、`python main.py backtest`、`python main.py report`。

# %%
from src.portfolio import generate_target_weights
from src.backtest import run_backtest

# generate_target_weights()
# run_backtest()
